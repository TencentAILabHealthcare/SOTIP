# %%
from sotip import *
import numpy as np
import scanpy as sc

# %%
adata_sotip
# Out:
# AnnData object with n_obs × n_vars = 1023 × 36
#     obs: 'row_num', 'point', 'cell_id', 'X1', 'center_rowcoord', 'center_colcoord', 'cell_size', 'category', 'donor', 'Cluster', 'leiden', 'ME_heter_Cluster_uniform', 'ME_heter_Cluster_paga_guided_umap', 'Cluster_knn', 'leiden_EMD', 'leiden_EMD_merge', 'min_dist_to_immune', 'min_dist_to_tumor', 'boundary_array', 'boundary'
#     var: 'sotip_polar_to_tumor', 'sotip_polar_to_tumor_bh', 'gt_polarized'
#     uns: 'Cluster_colors', 'Cluster_knn_colors', 'Cluster_sizes', 'GD', 'MEidx', 'boundary_colors', 'leiden', 'leiden_EMD_colors', 'leiden_EMD_merge_colors', 'leiden_EMD_merge_sizes', 'leiden_EMD_sizes', 'leiden_colors', 'merge_cls_list', 'neighbors', 'neighbors_EMD', 'paga', 'point_colors', 'umap'
#     obsm: 'ME', 'X_umap', 'X_umap_EMD', 'dummy_X', 'spatial'
#     obsp: 'connectivities', 'distances'

# %%
adata_sotip = sc.read_h5ad('sotip_polar_test_p16.h5ad')

# %%
adata_spagcn = sc.read_h5ad('../spagcn_result/spagcn_polar_test_p16.h5ad')

# %%
sotip_sorted_immune = adata_sotip.var.sort_values(by='sotip_polar_to_tumor_bh')

# %%
sotip_sorted_immune
# Out:
#            sotip_polar_to_tumor  sotip_polar_to_tumor_bh  gt_polarized
# vimentin           8.128562e-12             2.926282e-10           0.0
# CD98               2.204197e-10             3.967554e-09           1.0
# H3                 6.612175e-10             7.934610e-09           0.0
# Ecad               9.208063e-09             8.287257e-08           0.0
# CD11c              1.874641e-07             1.349741e-06           1.0
# CPT1A              7.782000e-07             4.669200e-06           1.0
# CD31               1.801629e-06             9.265519e-06           0.0
# NRF2p              1.504107e-05             5.760851e-05           0.0
# CD39               1.566157e-05             5.760851e-05           0.0
# CS                 1.600236e-05             5.760851e-05           1.0
# CK                 2.000623e-05             6.547494e-05           0.0
# VDAC1              3.482803e-05             1.044841e-04           1.0
# ATP5A              2.007714e-04             5.559822e-04           0.0
# NaKATPase          2.452235e-04             6.305748e-04           0.0
# SDHA               3.329093e-04             7.390203e-04           1.0
# CD14               3.489818e-04             7.390203e-04           0.0
# HK1                3.114912e-04             7.390203e-04           0.0
# GLUT1              4.263745e-04             8.527491e-04           1.0
# CD4                5.568246e-04             1.002284e-03           0.0
# LDHA               5.514207e-04             1.002284e-03           1.0
# PKM2               2.828328e-03             4.848563e-03           1.0
# CD45               3.156132e-03             5.164580e-03           0.0
# HIF1A              3.479014e-03             5.445413e-03           0.0
# G6PD               6.709860e-03             1.006479e-02           1.0
# XBP1               8.942741e-03             1.287755e-02           1.0
# ASCT2              9.641244e-03             1.334941e-02           1.0
# CD68               2.009161e-02             2.678881e-02           0.0
# Ki67               2.301999e-02             2.959713e-02           0.0
# CD8                4.853319e-02             6.024810e-02           0.0
# IDH2               8.818214e-02             1.058186e-01           0.0
# CD57               1.565161e-01             1.817606e-01           0.0
# CD3                2.337498e-01             2.629685e-01           0.0
# CD36               2.924571e-01             3.190441e-01           0.0
# PD1                4.708568e-01             4.985543e-01           0.0
# SMA                1.000000e+00             1.000000e+00           0.0
# S6p                9.999098e-01             1.000000e+00           0.0

# %%
adata_spagcn.var
# Out:
#            spagcn_polar_to_tumor  gt_polarized  spagcn_polar_to_tumor_bh
# H3                      0.000038           0.0                  0.001353
# vimentin                0.000378           0.0                  0.006811
# SMA                     0.976427           0.0                  0.999936
# CD98                    0.013501           1.0                  0.162007
# NRF2p                   0.585903           0.0                  0.999936
# CD4                     0.755460           0.0                  0.999936
# CD14                    0.231032           0.0                  0.756103
# CD45                    0.987076           0.0                  0.999936
# PD1                     0.743833           0.0                  0.999936
# CD31                    0.053672           0.0                  0.351092
# SDHA                    0.647470           1.0                  0.999936
# Ki67                    0.107222           0.0                  0.482500
# CS                      0.524271           1.0                  0.999936
# S6p                     0.999936           0.0                  0.999936
# CD11c                   0.223402           1.0                  0.756103
# CD68                    0.203457           0.0                  0.756103
# CD36                    0.568186           0.0                  0.999936
# ATP5A                   0.585364           0.0                  0.999936
# CD3                     0.952142           0.0                  0.999936
# CD39                    0.788856           0.0                  0.999936
# VDAC1                   0.058515           1.0                  0.351092
# G6PD                    0.745548           1.0                  0.999936
# XBP1                    0.361081           1.0                  0.999936
# PKM2                    0.497792           1.0                  0.999936
# ASCT2                   0.703688           1.0                  0.999936
# GLUT1                   0.742431           1.0                  0.999936
# CD8                     0.960297           0.0                  0.999936
# CD57                    0.635137           0.0                  0.999936
# LDHA                    0.942288           1.0                  0.999936
# IDH2                    0.828819           0.0                  0.999936
# HK1                     0.983154           0.0                  0.999936
# Ecad                    0.721272           0.0                  0.999936
# CPT1A                   0.378238           1.0                  0.999936
# CK                      0.055441           0.0                  0.351092
# NaKATPase               0.923157           0.0                  0.999936
# HIF1A                   0.073563           0.0                  0.378323

# %%
adata_sotip.var
# Out:
#            sotip_polar_to_tumor  sotip_polar_to_tumor_bh  gt_polarized
# H3                 6.612175e-10             7.934610e-09           0.0
# vimentin           8.128562e-12             2.926282e-10           0.0
# SMA                1.000000e+00             1.000000e+00           0.0
# CD98               2.204197e-10             3.967554e-09           1.0
# NRF2p              1.504107e-05             5.760851e-05           0.0
# CD4                5.568246e-04             1.002284e-03           0.0
# CD14               3.489818e-04             7.390203e-04           0.0
# CD45               3.156132e-03             5.164580e-03           0.0
# PD1                4.708568e-01             4.985543e-01           0.0
# CD31               1.801629e-06             9.265519e-06           0.0
# SDHA               3.329093e-04             7.390203e-04           1.0
# Ki67               2.301999e-02             2.959713e-02           0.0
# CS                 1.600236e-05             5.760851e-05           1.0
# S6p                9.999098e-01             1.000000e+00           0.0
# CD11c              1.874641e-07             1.349741e-06           1.0
# CD68               2.009161e-02             2.678881e-02           0.0
# CD36               2.924571e-01             3.190441e-01           0.0
# ATP5A              2.007714e-04             5.559822e-04           0.0
# CD3                2.337498e-01             2.629685e-01           0.0
# CD39               1.566157e-05             5.760851e-05           0.0
# VDAC1              3.482803e-05             1.044841e-04           1.0
# G6PD               6.709860e-03             1.006479e-02           1.0
# XBP1               8.942741e-03             1.287755e-02           1.0
# PKM2               2.828328e-03             4.848563e-03           1.0
# ASCT2              9.641244e-03             1.334941e-02           1.0
# GLUT1              4.263745e-04             8.527491e-04           1.0
# CD8                4.853319e-02             6.024810e-02           0.0
# CD57               1.565161e-01             1.817606e-01           0.0
# LDHA               5.514207e-04             1.002284e-03           1.0
# IDH2               8.818214e-02             1.058186e-01           0.0
# HK1                3.114912e-04             7.390203e-04           0.0
# Ecad               9.208063e-09             8.287257e-08           0.0
# CPT1A              7.782000e-07             4.669200e-06           1.0
# CK                 2.000623e-05             6.547494e-05           0.0
# NaKATPase          2.452235e-04             6.305748e-04           0.0
# HIF1A              3.479014e-03             5.445413e-03           0.0

# %%
polar_join = adata_sotip.var[['sotip_polar_to_tumor_bh','gt_polarized']]

# %%
# Out:
# 12.0

# %%
fdr_array = np.arange(0,0.5,0.01)
pd_dict = {
    'fdr':[],
    'power':[],
    'method':[]
}
gt_polar_count = np.sum(polar_join['gt_polarized'])
for fdr in fdr_array:
    sotip_polar_count = np.sum(polar_join[polar_join['sotip_polar_to_tumor_bh']<=fdr]['gt_polarized'])
    spagcn_polar_count = np.sum(polar_join[polar_join['spagcn_polar_to_tumor_bh']<=fdr]['gt_polarized'])  
    
    sotip_power = sotip_polar_count/gt_polar_count
    spagcn_power = spagcn_polar_count/gt_polar_count
    pd_dict['fdr'].append(fdr)
    pd_dict['power'].append(sotip_power)    
    pd_dict['method'].append('sotip')    
    
    pd_dict['fdr'].append(fdr)
    pd_dict['power'].append(spagcn_power)    
    pd_dict['method'].append('spagcn')    
pd_df = pd.DataFrame(pd_dict)

# %%
cmp = palettable.cartocolors.qualitative.Bold_10.mpl_colors[0:2]

g = sns.lineplot(data=pd_df,x='fdr',y='power',hue='method',palette=cmp)
g.legend_.remove()
plt.title('scMEP_p16')
# Out:
# Text(0.5, 1.0, 'scMEP_p16')
